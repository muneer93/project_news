# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
from dotenv import load_dotenv
import os
from youtube_transcript_api import YouTubeTranscriptApi

# %%
CHANNELS = [
    {"id": "UCXIJgqnII2ZOINSWNOGFThA", "name": "Fox News"},
    {"id": "UCupvZG-5ko_eiXAupbDfxWw", "name": "CNN"},
    {"id": "UCBi2mrWuNuyYy4gbM6fU18Q", "name": "ABC News"},
    {"id": "UC16niRr50-MSBwiO3YDb3RA", "name": "BBC News"},
    {"id": "UCuFFtHWoLl5fauMMD5Ww2jA", "name": "CBC News"},
    {"id": "UCi7Zk9baY1tvdlgxIML8MXg", "name": "CTV News"},
    {"id": "UCwqusr8YDwM-3mEYTDeJHzw", "name": "Republic TV"},
    {"id": "UCt4atlExw8aj3Bm79nv1fig", "name": "Times Now"},
    {"id": "UCw8Fc5R0Q5yyS3KrDCPM3xg", "name": "Times Now World"},
    {"id": "UC_gUM8rL-Lrg6O3adPW9K1g", "name": "WION"},
    {"id": "UCYPvAwZP8pZhSMW8qs7cVCw", "name": "India Today"},
    {"id": "UCaXkIU1QidjPwiAYu6GcHjg", "name": "MSNBC"},
    {"id": "UCNye-wNBqNL5ZzHSJj3l8Bg", "name": "Al Jazeera English"},
    {"id": "UChLtXXpo4Ge1ReTEboVvTDg", "name": "Global News"},
]

# %%
load_dotenv()

class YouTubeAPIClient:
    def __init__(self):
        # Load and clean keys
        keys = os.getenv("YOUTUBE_API_KEYS")
        if not keys:
            raise ValueError("No API keys found in file.")
        self.api_keys = [key.strip() for key in keys.split(',')]
        self.index = 0
        self.youtube = self._build_client(self.api_keys[self.index])

    def _build_client(self, key):
        return build("youtube", "v3", developerKey=key)

    def _rotate_key(self):
        self.index += 1
        if self.index >= len(self.api_keys):
            raise Exception("All API keys exhausted.")
        print(f"Switching to next API key: {self.api_keys[self.index]}")
        self.youtube = self._build_client(self.api_keys[self.index])

    def execute(self, request):
        while True:
            try:
                return request.execute()
            except HttpError as e:
                error_res = e.resp.get('status')
                if error_res == 403 and 'quotaExceeded' in str(e):
                    print(f"Quota exhausted for API key {self.api_keys[self.index]}")
                    self._rotate_key()
                else:
                    raise e

    def get_client(self):
        return self.youtube

yt_client = YouTubeAPIClient()
youtube = yt_client.get_client()

# %%
# Step 2: Get Channel Statistics
def get_channel_stats(channel_id):
    try:
        request = youtube.channels().list(
            part='snippet,statistics',
            id=channel_id
        )
        response = request.execute()
        data = response['items'][0]
        stats = data['statistics']
        return {
            'channel_id': channel_id,
            'channel_title': data['snippet']['title'],
            'subscriber_count': int(stats.get('subscriberCount', 0)),
            'total_views': int(stats.get('viewCount', 0)),
            'video_count': int(stats.get('videoCount', 0))
        }
    except Exception as e:
        print(f"Error getting channel stats for {channel_id}: {e}")
        return None

# %%
get_channel_stats('UCYPvAwZP8pZhSMW8qs7cVCw')
# Out:
# {'channel_id': 'UCYPvAwZP8pZhSMW8qs7cVCw',
#  'channel_title': 'India Today',
#  'subscriber_count': 10400000,
#  'total_views': 4827499456,
#  'video_count': 236181}

# %%
# Capture video details

def get_video_data(video_id):
    try:
        request = youtube.videos().list(
            part="snippet,statistics",
            id=video_id
        )
        response = request.execute()

        if response['items']:
            video = response['items'][0]
            snippet = video['snippet']
            statistics = video['statistics']
            video_data = {
                'video_id': video_id,
                'title': snippet['title'],
                'description': snippet['description'],
                'published_at': snippet['publishedAt'],
                'views': int(statistics.get('viewCount', 0)),
                'likes': int(statistics.get('likeCount', 0)),
                'dislikes': int(statistics.get('dislikeCount', 0)),
                'comment_count': int(statistics.get('commentCount', 0))
            }
            return video_data
        else:
            print(f"No data found for video ID: {video_id}")
            return None
    except Exception as e:
        print(f"Error getting video data for {video_id}: {e}")
        return None

# %%
get_video_data('hLG0tvZ7hi0')
# Out:
# {'video_id': 'hLG0tvZ7hi0',
#  'title': 'US President Donald Trump arrives in Saudi Arabia, meets MBS',
#  'description': "US President Donald Trump’s plane has touched down in Riyadh on first stop in three-country trip.\nSaudi Crown Prince Mohammed bin Salman has welcomed Trump at the tarmac of the airport in Riyadh.\n\nAl Jazeera's Kimberly Halkett and Hashem Ahelbarra is monitoring developments in Riyadh, Saudi Arabia. \n\nSubscribe to our channel: http://bit.ly/AJSubscribe\nFollow us on X: https://x.com/ajenglish\nFind us on Facebook: https://www.facebook.com/aljazeera\nCheck our website:  https://www.aljazeera.com\nCheck out our Instagram page: https://www.instagram.com/aljazeeraenglish\nDownload AJE Mobile App: https://aje.io/AJEMobile\n\n#DonaldTrump #SaudiArabia #Riyadh #PrinceMohammedbinSalman #MBS #TrumpGulfVisit #MiddleEast #AlJazeeraEnglish",
#  'published_at': '2025-05-13T07:31:42Z',
#  'views': 432855,
#  'likes': 4351,
#  'dislikes': 0,
#  'comment_count': 1079}

# %%
video_id='hLG0tvZ7hi0'
def get_captions(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
        return [entry['text'] for entry in transcript]
    except Exception as e:
        print(f"Error getting transcript for {video_id}: {e}")
        return []

# Fetch and print the captions
captions = get_captions(video_id)
for line in captions:
    print(line)
# Out:
# Let's now go to our White House
# correspondent Kimbley Halit. She is
# normally in Washington DC, but today she
# is in Riad to follow this visit. And
# Kimbley, we're expecting to see the
# Saudi Crown Prince Muhammad bin Salman
# uh at the international airport there in
# Riyad where US President Donald Trump
# has just touched down. Uh Trump can
# expect a full red carpet welcome, can't
# he?
# Yeah, literally the red carpet is
# expected to be rolled out for Donald
# Trump. He is expected to have a very
# similar lavish welcoming ceremony much
# like we saw in 2017. The sword dance is
# expected to be part of that traditional
# welcoming ceremony. He was uh offered a
# a gold medal, one of the highest
# civilian honors the f during his first
# term. We expect something similar again
# this time. But in terms of all of the
# opulence that will be afforded to Donald
# Trump, this is something that Donald
# Trump likes. But at the same time, he's
# also heavily criticized back in the
# United States for the fact that he has a
# very close relationship with the Saudi
# crown prince. And that comes for a
# number of reasons. Uh because he is
# criticized for the fact that he has uh
# mixed in many ways business with
# pleasure. Many argue that he who is he
# representing? Is he representing the
# American people or is he representing
# his own business interests? And uh he
# has really blurred the lines when it
# comes to this trip. when he you look at
# this as his first major foreign trip of
# his second term, he has once again just
# as he did in his first term departed
# with modern presidential history. Uh
# typically what we see is his
# predecessors using their first major
# foreign trip to visit a neighboring
# ally, whether it would be Canada,
# Mexico, or whether it would be uh a NATO
# ally. In this case, Donald Trump has
# chosen to go to uh Saudi Arabia both
# times. And the fact that he has gone to
# Saudi Arabia and then on to other Gulf
# countries is significant given the fact
# that he has got business interest there.
# In recent weeks, it has been noticed
# that his sons have gone to uh Dubai,
# have gone to in the United Arab
# Emirates, where Donald Trump will also
# be going, have business ventures in
# Qatar, where there are uh projects, real
# estate projects as well as
# cryptocurrency ventures. Uh so it's not
# just Saudi Arabia where the Trump
# organization
# has ventures and real estate projects
# going and this has really opened up
# Donald Trump to criticism back
# domestically in the United States. So
# while Donald Trump says that he is here
# to acquire business investment to the
# tune of $1 trillion dollar in defense
# spending for the United States from the
# Saudis and this is about deepening and
# strengthening security ties. There is
# also as a real estate mogul obviously
# going to be benefit for Donald Trump's
# organization and that has really opened
# him up to the optics and the criticism
# that he is intertwining both business
# and in fact he is benefiting. Now, we
# should also point out in all of this
# that uh this really does underscore that
# there is a strong and warm relationship.
# And as we look at the the pictures of
# Air Force One, the carpet rolled out
# there is not a red carpet but a blue
# carpet that we see. We do acknowledge
# that there is going to be this this
# ceremonial aspect to this visit. It is
# diplomacy that is going to be first and
# foremost and forefront of this visit.
# There is going to be a political aspect
# to this, but there are also enormous
# security challenges that Donald Trump is
# facing during this trip. Looming over
# this trip, of course, is the enormous
# challenge of Israel's war on Gaza. In
# Donald Trump's first trip to Saudi
# Arabia in his first term, he did include
# a stop in Israel. That will not be
# taking place this time around. And the
# White House has said that is because
# there has been no progress on an
# immediate ceasefire talk. And so as a
# result, Donald Trump will not be going
# to Israel in his secondterm trip. This
# issue of Israel expanding its military
# operations. The famine is something that
# is looming over this trip like a dark
# cloud and a very dark shadow. the fact
# that there has been no progress there
# and the White House has not been able to
# make any sort of influence or headway in
# with the Israeli government with respect
# to Israel's war on Gaza. There is also
# the issue of the ongoing war in Ukraine
# and the fact that that is looming as
# well.
# Kimberly, this is Darina. I've taken
# over from Laura this hour. We're looking
# at the live pictures uh Donald Trump
# awaiting um him to come out of that
# plane. But just remind us who's joined
# him on this trip and talk us through
# what we expect to see over the next few
# hours while he's in Saudi Arabia.
# Yeah. What we know is that there is
# going to be a large delegation that will
# be traveling with the president. We know
# that the defense secretary Pete Hedgeth
# will be accompanying the president. Uh
# that is understandable given the
# enormous security spending defense
# contracts that are expected to take
# place. That is a primary goal of this
# trip. So the defense secretary peach
# heads as well given the fact that there
# are big regional security concerns. Iran
# is another big discussion point that
# will be taking place. The fact that in
# uh that Marco Rubio, the secretary of
# state, also the national security
# adviser, is on board the airplane, Air
# Force One, he is also here. Uh that is
# an important point to make here. This
# trip versus uh the first time Donald
# Trump was in his first term. Iran and
# the role that Saudi Arabia plays with
# respect to Iran is very different this
# time around. When uh the United States
# came to discuss Iran in Donald Trump's
# first term, it was about talking to
# Saudi Arabia and trying to isolate Iran
# to try and deal with what it saw as an
# extremist element. This time around,
# it's about trying to work with Iran,
# trying to uh to limit its nuclear
# program and even discuss the potential
# for a civil nuclear program. It's a very
# different tone. That is why the
# secretary of state is so instrumental
# this time around. We also know that uh
# there is a big business aspect. So there
# are key business leaders traveling with
# the US president as well. So there is an
# enormous delegation but it's very key
# that those players are alongside the
# president as he is preparing to exit Air
# Force One. Okay, Kimberly, we'll cross
# back to you uh shortly. I'm going to
# bring in Hashim Abb right now who's also
# joining us from Riyad. And we're keeping
# that live picture. We wait for Donald
# Trump to exit Air Force One any moment
# now. But Hashim, um, let's bring you in
# because look, in March, Trump said this.
# He said he'd go to Saudi Arabia if it
# invests $1 trillion in the US. Now, the
# Saudis haven't confirmed that figure,
# but what are the Saudis looking to get
# from the US?
# Well, it's is going to be mainly about
# trade agreements, major trade
# agreements. How much are they going to
# commit over the la upcoming years? That
# remains to be seen. But we're talking
# about
# potentially hundreds of billions of
# dollars of arms agreement providing the
# Saudis with new military capabilities.
# And uh one of the agreements is going to
# be about uh air-to-air missiles which
# are going to be equipped for the Saudi
# fighter jets. But then the the major
# issue is going to be a security pact
# which both countries have been trying to
# work out the details for quite some
# time. It was potentially going to be
# finalized during the Biden
# administration, but it didn't further
# materialize because of huge differences
# particularly over the some of the string
# that were attached to the agreement. The
# potential for a a a diplomatic overtures
# towards Israel. The Saudis remain of the
# view that that will only happen, the
# normalization when the peace talks
# between the Israelis and the
# Palestinians conducive to a Palestinian
# state are on a solid uh ground. Let me
# update you on some of the stuff we're
# expecting to see happening today and
# most importantly tomorrow. So today,
# later in the day, we're going to see
# Crown Prince Muhammad bin Salman along
# with President Trump meeting with Saudi
# and with American investors. And this is
# where they're going to announce some
# major agreements particularly when it
# comes to artificial intelligence
# technology uh real estate and also the
# arms agreements which are going to be
# later announced. Then the highlight is
# going to be tomorrow when the Saudis are
# going to invite GCC leaders to meet with
# President Donald Trump. been in touch
# with a senior official in Damascus who
# confirmed to me that President Ahmed
# Shah is going to travel tomorrow to
# Riyad and this if it happens is going to
# be quite a significant development. It
# could be an indication that the uh the
# the Saudis are trying to push for an
# American recognition of the new
# authority, but most importantly seeing
# whether the Americans are going to ease
# the sanctions on the new government in
# in Damascus if that happens is going to
# pave the way for a significant
# geopolitical shift in the uh region. And
# finally, when you talk to the Saudis
# about why is this is significant from a
# Saudi perspective, they say this is a
# unique opportunity for both the Saudis,
# for the Americans and for the region.
# Now, Saudi Arabia has managed to expand
# its influence regionally, building ties
# with the new authorities in Syria,
# trying to mediate agreements in the
# region, ensure that there's going to be
# the potential for a ceasefire, also in
# Yemen, uh particularly with the Houthis.
# And the reason why they're doing this is
# to convince President Donald Trump on
# the need to rely on Saudi Arabia as a
# key regional mediator. And this is
# tomorrow going to be the moment when
# they will talk about Gaza and what
# happens next for Gaza. And this is where
# the Saudis are saying that they're going
# to play quite a significant role, not
# only in putting together the final
# touches of what happens there, but also
# to ensure the potential for resumption
# of talks between the Palestinians and
# the Israelis. And this is a quite
# significant condition for the Saudis.
# They say without which there's
# absolutely no way we can talk about
# normalization between Saudi Arabia and
# also uh the and Israel. And that is
# going to be the the first step. Now
# Trump is going to travel to Qatar. which
# is also where where he's going to
# explore the potential for other
# mediations when when it comes to the
# Middle East and later to the United Arab
# Emirates where he's likely to also
# announce major trade agreements
# particularly when it comes to artificial
# intelligence where the Amiratis say that
# over the next 10 years they're going to
# commit themselves a trillion dollars to
# become a a leader in
# artificial intelligence and this is why
# the Saudis when you look at at the at
# the event which is going to happen now.
# The the the official reception by Crown
# Prince Muhammad bin Salman and the
# gatherings which are going to happen
# tomorrow. The dynamics which are at
# play. You will see that the common
# thread among all these elements is
# Saudis positioning themselves as the
# most important geopolitical player in
# this region. sending a message to the
# Americans that if you want to fix
# problems in Lebanon and Syria, for
# example, you have to come to us. If you
# want to see stability in the region for
# the potential of an agreement with the
# Iranians, you have to come to us. If you
# want to have an agreement or to pacify
# the Houthies in Yemen, you have to come
# to us because we share borders and we
# have huge stakes there in Yemen. And
# they are using that to their own
# advantage. I've been talking to people
# here about what they read into this
# particular visit of Trump to Saudi
# Arabia and they say it's very simple.
# It's very obvious. Saudi Arabia is
# saying
# that Trump likes to deal business with
# extremely powerful wealthy nations and
# we are one of those wealthy, extremely
# powerful nation in this part of the
# world. And therefore we see the
# potential for uh us and this and the
# Americans to team up for major major
# geopolitical shifts which are likely to
# happen in the upcoming years across the
# region. The repercussions of what
# happens today. This is Grand Prince
# Muhammad bin uh Salman uh uh coming to
# the as you can see now to uh to the
# airport and to tarmac and uh waiting for
# President Donald Trump uh uh to uh come
# downstairs and this is going to be quite
# a significant moment for the Saudi crown
# prince who has been playing quite some
# key re key important roles in the
# region. He is for the time being the
# most powerful leader in this part of the
# world and using
# that that
# leverage with the Americans to try to
# sort out some of the problems which are
# still uh in this part of the world
# particularly the Palestinian problem and
# particularly what is happening uh in
# Gaza.
# Yeah. Hashim. So we're looking at the
# the live picture that was Muhammad bin
# Salman uh just a moment ago. uh walking
# to the aircraft Air Force One. Uh Donald
# Trump's plane uh landed just a short
# time ago in Saudi Arabia and this is uh
# kicking off uh the US president's first
# major international tour of his second
# term as we've been reporting. Hasham,
# you talked a lot about some of the
# regional issues that may be discussed in
# Saudi Arabia with the Saudis, but on the
# point you make on Gaza and the
# Palestinians. So, are we to understand
# that that issue of normalization is now
# completely off the table because the
# Saudis have said that Riad won't
# normalize. Oh, there he is. There is uh
# there is Donald
# Trump walking out of uh Air Force One.
# coming down the the stairs and as
# Kimberly was pointing out just a short
# while ago, they've uh they've unveiled
# the the blue carpet uh for Donald Trump
# in Riad. Hashim, back to you. Just talk
# us through the symbolism of all of this.
# So this is exactly a repeat of what
# happened when Trump was first elected.
# He he broke with a long tradition of US
# presidents choosing Saudi Arabia as his
# first overseas destination. He made the
# same thing today and this is widely
# perceived here in Saudi Arabia as quite
# a vindication of their ever growing
# role. They say that they can use this
# particular moment to foster ties with
# the Americans to try to solve many many
# regional players. You've asked me about
# Gaza and why Gaza is going to be
# significant. They will talk about it and
# they are the two players who have all
# the leverage to try to sort out what
# happens in Gaza. of course along with
# the help of other regional players Kata
# in particular which has been working
# hard over the past two years to try to
# negotiate a settlement to Gaza and why
# for the Saudis this is quite crucial
# quite important because they saw that
# there's been this push in the past to
# for a normalization between the Saudis
# and the Israelis but because you know
# Saudi Arabia always acts as a regional
# leader and therefore when they take a
# step they have to cautiously calculate
# what happens next and the repercussions
# of the first step. They say for us to
# move forward towards normalizing ties
# with Israel, we have to ensure that Gaza
# ceasefire is implemented and but above
# all there is
# a talk between the Palestinians and the
# Israelis that is going to be conducive
# to a Palestinian state which has to be
# backed by the international community on
# this particular thing.
# The Saudis have launched this new called
# um initiative for the two-state solution
# which is going to be happening in June
# in New York. The French president
# Emmanuel Macron is going to chair that
# summit with with the Saudis and they are
# building a momentum towards it and many
# European countries back it to the point
# where many governments have been saying
# that we should consider recognizing the
# Palestinian state to give more momentum
# towards this new initiative that is
# launched by Saudi Arabia. But when you
# talk about the very details of this
# thing, it has to be decided by Saudi
# Arabia. And this explains why they are
# inviting GCC leaders tomorrow to this
# meeting with Donald Trump because this
# is why they will listen to
# the powerful GCLC leaders and have them
# on board. and they hope that this could
# be conducive to a consensus that could
# help the Americans and the Saudis to
# build more uh of a consensus among Arab
# leaders on the need to move towards this
# track. Now, from a Saudi perspective,
# it's very difficult to sort out the
# problem in Gaza if you don't have an
# international umbrella, but at the same
# time, if you don't kickstart a genuine
# political process between the
# Palestinians and between the Israelis
# and the Saudis have been in touch with
# the uh with with the Palestinians. The
# deputy president has of Palestine or the
# Palestinian Authority has been, this is
# Marco Rubio, with Crown Prince Muhammad
# bin Salman. They have he was here in
# Riyad for a visit with the crown prince.
# It it's you you get elements that many
# path path are on track now with huge
# influence from Saudi Arabia which wants
# to sort out some of those things. If it
# happens it's just further
# acknowledgement of the ever growing role
# for Saudi Arabia. And by the way, when
# you read the newspapers, when you see
# the talk shows here in Riyad, they talk
# about the trade agreements, the arms
# agreements, but they say this is not
# just necessarily about Saudi Arabia
# committing financial itself to financial
# agreements with Saudi Arabia, with the
# United States of America or investing
# hundreds of billions of dollars in s in
# in in the American market. But it's more
# about Saudi Arabia repositioning itself
# as the most important player in the
# region. And by the way, when you look at
# the Middle East over the last few
# months, we've seen some seismic shifts
# the when Bashar al-Assad was toppled in
# Syria that that has in a way eroded
# Iran's clout in the region and paved the
# way for Saudi Arabia's ever growing
# presence. And this explains the strong
# relations that we've seen over the past
# few months between Saudi Arabia and the
# new authorities in Damascus. This all
# bits when you put them together it gives
# you more sense of clarity about the
# dynamics we are which are shifting in
# this part of the world and the and most
# important take away from it is that
# whatever is going to be decided tomorrow
# today and tomorrow here in Riyad will
# have huge impact on what happens next
# across the region particularly when it
# comes to Gaza Palestinian Israeli issue
# normalization with Israel and also
# stability in the Middle East, what
# happens in Syria and also what happens
# in Yemen and Lebanon. They are all
# interrected, but they're interconnected,
# but the threat there is Saudi presence,
# Saudi influence.
# Hashim, uh, we're just looking at the
# live picture. Uh, I'm sure you can see
# what we're seeing. I don't mean to put
# you on the spot here, but um perhaps you
# can talk to us a little bit about what
# is going on right now. I mean, we saw uh
# some of Trump's entourage. We saw uh
# Pete Hegth. We saw Marco Rubio with him
# as well. Uh tell us who's joined him and
# what we're looking at right now and what
# the next few hours will bring.
# It is going to be an extremely busy day
# for both uh leaders. uh uh after after
# after uh after this meeting at the
# airport, Trump is going to go to his
# residence and then he will meet with uh
# crown prince in the uh royal diwan and
# then they will go together and meet with
# Saudi and American investors and this is
# where they will be talking about the
# potential for trade agreements. The
# Saudis said that they were willing to
# further expend some of those agreements
# and they uh they were willing to invest
# hundreds of billions of dollars over the
# next few years. Trump has been talking
# about a trillion dollar that he wants to
# see the Saudis commit. But all in all,
# if you look at the security pact, the uh
# the the the the the civilian nuclear
# energy and the arms deal plus the
# agreements on artificial intelligence
# and technology real estate, we're
# talking about potentially hundreds of
# billions of dollars which Saudi Arabia
# is going to have to uh invest over the
# next few years and as far as Trump is
# concerned is going to
# an indication that his transactional uh
# approach is working. Good news for him
# to bring back home. But as far as the
# Saudis is concerned, this is just one
# step forward. Later in the day, there
# will be more uh of meetings between the
# Saudi crown prince and the American
# president followed by an official
# dinner. But throughout the day, this is
# where they're going to also talk about
# all the other key regional play uh key
# regional issues where the Saudis are
# particularly trying to convince the
# Trump administration to ease the
# sanctions on the on Syria and for them
# is this is very important for different
# reasons. first of all because is going
# to bring about a sense of stability more
# of an international recognition for the
# new government in Syria but also ease
# the tension. One of the issues which
# have been debated is the potential for
# the Americans to invest in Syria and
# also to look for the potential for what
# happens in uh the border area between
# Israel and Syria to prevent any
# escalation that could further
# destabilize the entire region. And on
# this particular issue, Saudi Arabia, you
# can see Trump greeting Saudi
# dignitaries. One of them
# is the Saudi ambassador to the United
# States of America. An extremely busy
# schedule for both leaders today and
# particularly tomorrow. I was saying that
# the they're looking forward to discuss
# Syria and what happens next in Syria.
# And the reason why the Saudis are very
# much into sorting out what happens in
# Syria because they see the potential for
# themselves to play quite a significant
# role. In the past five decades uh during
# the the al-Assad family rule in Syria,
# they were more towards stronger
# relations with Iran. Now the Saudis see
# the potential for themselves to be the
# key regional player in the region with
# with with fostering ties and this is why
# they have been providing
# significant assistance to the to the
# Saudis along with Katar which has also
# stepped up its support for the new
# authorities in Syria and and later they
# will discuss also Iran and they will
# also discuss uh uh Gaza but it's going
# to be tomorrow where also you will see a
# different choreography, a set of
# choreography basically Prince Muhammad
# Bman along with Trump greeting GCC
# leaders and further expanding the talks
# about the issues that are at stake
# ultimately after this and when you look
# at what is at stake for the Trump
# administration flying to Qatar
# negotiating the potential for more
# agreements and that's where also Gaza is
# going to be a key issue. to be debated
# and then flying to the United Arab
# Emirates. I think he wants to ensure
# that he will be securing major major
# trade agreements and come back to his
# people and say look my policy is
# working, my style is working and coming
# back home with hundreds of billions of
# dollars and I'm fixing the problems in
# the entire world. But ultimately, you
# can only do that when you have the
# backing of the GCC, wealthy nations,
# particularly Saudi Arabia. So, it's a
# win-win scenario for the two men who are
# leading the talks today, Crown Prince
# Muhammad Salman, bin Salman, and at the
# same time, President Donald Trump. Okay,
# Aashim, we'll let you go for now. We'll
# cross back to you a little later on.
# Thank you so much for that reporting
# from Ariads.

# %%
def get_video_comments(video_id, max_comments=500):
    comments = []
    next_page_token = None
    total_fetched = 0

    while total_fetched < max_comments:
        try:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
                textFormat="plainText"
            )
            response = yt_client.execute(request)

            for item in response["items"]:
                top_comment = item["snippet"]["topLevelComment"]["snippet"]
                comment_data = {
                    "comment_id": item["snippet"]["topLevelComment"]["id"],
                    "author": top_comment.get("authorDisplayName"),
                    "text": top_comment.get("textDisplay"),
                    "like_count": top_comment.get("likeCount"),
                    "published_at": top_comment.get("publishedAt"),
                    "reply_count": item["snippet"].get("totalReplyCount", 0),
                    "replies": []
                }

                # Capture replies if any
                if "replies" in item:
                    for reply in item["replies"]["comments"]:
                        reply_snippet = reply["snippet"]
                        comment_data["replies"].append({
                            "author": reply_snippet.get("authorDisplayName"),
                            "text": reply_snippet.get("textDisplay"),
                            "like_count": reply_snippet.get("likeCount"),
                            "published_at": reply_snippet.get("publishedAt"),
                        })

                comments.append(comment_data)
                total_fetched += 1

                if total_fetched >= max_comments:
                    break

            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break

        except Exception as e:
            print(f"Error fetching comments: {e}")
            break

    return comments

# %%
video_id = "hLG0tvZ7hi0"
comments = get_video_comments(video_id, max_comments=300)
print(f"Total comments fetched: {len(comments)}")
# Out:
# Total comments fetched: 300

# %%
def comments_to_dataframe(comments):
    rows = []

    for comment in comments:
        # Top-level comment
        rows.append({
            "username": comment["author"],
            "comment": comment["text"],
            "type": "comment"
        })

        # Replies (if any)
        for reply in comment.get("replies", []):
            rows.append({
                "username": reply["author"],
                "comment": reply["text"],
                "type": "reply"
            })

    return pd.DataFrame(rows)

# %%
video_id = "hLG0tvZ7hi0"
comments = get_video_comments(video_id, max_comments=300)

df_comments = comments_to_dataframe(comments)
df_comments.head()
# Out:
#             username                                            comment  \
# 0  @mdfahidahmmed320  Gaza cries. Blood flows where prayers once ech...
# 1        @xvizcaino4  Best President ever . God bless you Donald Tru...
# 2     @jamesbomd3503  I don't think Al Jazeera should worry about Do...
# 3        @tomlaz2039  And he walked away with a trillion dollar deal...
# 4    @TafLOVERohayla  🤔You meant the United state airplane ✈️ is obv...
#
#       type
# 0  comment
# 1  comment
# 2  comment
# 3  comment
# 4  comment

# %%
df_comments[df_comments['type'] == 'reply']
# Out:
#                      username  \
# 30             @SuzetteSmetka
# 77                 @rattata30
# 78                   @fa1rumi
# 80                 @rattata30
# 129           @meganalves9967
# 130           @Ibn.Hadarmuud.
# 208        @beyesteadfast8488
# 209          @hubertmatos5920
# 210               @MrAdam2853
# 214             @sheila-we7em
# 221            @SuzetteSmetka
# 231              @SadaK-tr6dm
# 243       @PalestineHere2Stay
# 244          @hubertmatos5920
# 245       @PalestineHere2Stay
# 246  @Haaatdfffvvvhhhteedddhj
# 248                @Na.wa.l.1
# 249                  @howbani
# 250                @Na.wa.l.1
# 262            @algorithm1635
# 267             @sheila-we7em
# 269             @sheila-we7em
# 288              @varaeva5903
# 289              @SadaK-tr6dm
# 290             @Yoyoniki-h3t
# 296              @varaeva5903
# 299                  @Sully-B
# 303                  @Sully-B
# 307              @varaeva5903
# 309              @varaeva5903
# 313                @Wolfoxxxx
# 318           @DominatusHydra
# 321              @varaeva5903
# 325              @varaeva5903
# 326      @mohamedazardeen8080
# 329           @DominatusHydra
# 331               @زيد-111-11
# 332          @ArtistHusna_Tee
# 333               @PAVEL-JAKL
# 334               @زيد-111-11
# 335       @SallyListrom-gq7yi
#
#                                                comment   type
# 30     Yeah, from one murderer to another. \nYou fool.  reply
# 77   I’m Catholic you are my brother in Christ! Hop...  reply
# 78   @@rattata30 May there be peace and happiness f...  reply
# 80   Not only that but the disrespect of not giving...  reply
# 129                 He’s not it’s called trade & deals  reply
# 130  @@meganalves9967 why doesn’t Trump get the onl...  reply
# 208                                     🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸  reply
# 209               Drink water, too much poison in you.  reply
# 210                                Its a business dead  reply
# 214                               IT'S NOT COKE COLA😁😁  reply
# 221  I guess you missed the report that he ordered ...  reply
# 231                                              💯 💯 💯  reply
# 243                              And medical equipment  reply
# 244        YES YES YES but be peaceful and respectful.  reply
# 245  @@hubertmatos5920 The people being bombed or t...  reply
# 246     Lindus keep your saympathy for your cow mother  reply
# 248                           تحلب 😂انت من تحلبك ايران  reply
# 249                 @ ههه ياخذ ايه الريح من البلاط ههه  reply
# 250  @@howbani  ايران غنية وتدفع للشر باستماته دفعت...  reply
# 262  Everything about the Palestinians for the mind...  reply
# 267  US CARE MORE ABOUT THE TARIFFS AND HOW TRUMP I...  reply
# 269  TRUMP HAS 2 FACES, HE IS PLAYING BOTH SIDES, J...  reply
# 288                                         not always  reply
# 289                                  The Child Killer?  reply
# 290  @SadaK-tr6dm  nice slogan. For too many years ...  reply
# 296                               for Palestinians too  reply
# 299  تراث سعوديه وتنتمي لزهور الخزامه التي تشتهر به...  reply
# 303                       تنتمي لزهور الخزامى السعودية  reply
# 307                                           lavender  reply
# 309                           should be pro israel? ))  reply
# 313  Saudi heritage-Lavender flower \nFamous in Ara...  reply
# 318                          And he's going to get it.  reply
# 321                                                  😂  reply
# 325                                           lavender  reply
# 326                              @@varaeva5903 exactly  reply
# 329                                       Arabian Gulf  reply
# 331  It's Saudi coffee. It seems that Trump does no...  reply
# 332              It's coffee. He might not take coffee  reply
# 333                            He doesn't drink coffee  reply
# 334  @@premkhan3969 I just watched a video of Trump...  reply
# 335  It was coffee. Trump doesn’t drink coffee, nev...  reply
